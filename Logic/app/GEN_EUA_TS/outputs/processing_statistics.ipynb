# %%
import os

from formulaic.utils.null_handling import drop_rows

instances = []
with open('..'+os.sep+'tests'+os.sep+'tests2Run.txt') as file:
    for line in file:
        if line[0] != '#' and line[0] != '\n':
            if '\n' in line:
                line = line[:-1]
            tokens = line.split('\t')
            instance = tokens[0]
            instances.append(instance)

for instance in instances:
    file = '..'+os.sep+'outputs'+os.sep+instance+'_statistics_.txt'
    with open(file) as f:
        print(file,f.read())
# Out:
# ../outputs/test_exp_3_statistics_.txt total jobs;total completed;total expired
# 2498;1916;582

# %%
import pandas as pd
from pymongo import MongoClient

# Connect to the MongoDB server
client = MongoClient('mongodb://localhost:27017/')
db = client['EUA_db']
collection = db['events_data']

# Retrieve data from the collection
data = list(collection.find())

# Filter events for jobs
job_events = [event for event in data if event['status'] in ['TypeEvent.user_arrival', 'TypeEvent.user_completed', 'TypeEvent.user_expired']]

# Create jobs DataFrame
jobs = pd.DataFrame(job_events)
jobs=jobs[['origin_id','time','status']]


jobs['id'] = 0
for indx,row in jobs.iterrows():
    msg = row['origin_id']
    jobs.loc[indx,'id'] = msg.split(' ')[1]
    
# display(jobs.head())


# Assuming `jobs` DataFrame is already created and contains the necessary data

# Group by 'id' and sort by 'time' in reverse order
jobs_sorted = jobs.sort_values(by=['id', 'time'], ascending=[True, False])

# Initialize a list to store the results
time_differences = []

# Iterate over each group
for _, group in jobs_sorted.groupby('id'):
    # Find the arrival time
    arrival_times = group[group['status'] == 'TypeEvent.user_arrival']['time'].values
    if len(arrival_times) == 0:
        continue
    
    
    # Find the expired/completed time
    arrival_time = float(arrival_times[0])
    # print(group)
    for _, row in group.iterrows():
        if row['status'] in ['TypeEvent.user_expired', 'TypeEvent.user_completed']:
            
            time_diff = float(row['time']) - arrival_time
            time_differences.append({
                'id': row['id'],
                'time_difference': time_diff
            })

# Convert the results to a DataFrame
time_diff_df = pd.DataFrame(time_differences)

# Display the result
display(time_diff_df)
time_diff_df.describe()
# Out:
# /tmp/ipykernel_44507/428678321.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   jobs.loc[indx,'id'] = msg.split(' ')[1]
#         id  time_difference
# 0        0             17.0
# 1        1             18.0
# 2       10             20.0
# 3      100             20.0
# 4     1000             15.7
# ...    ...              ...
# 4409   997              1.0
# 4410   998              4.0
# 4411   998              4.0
# 4412   999             10.9
# 4413   999             10.9
#
# [4414 rows x 2 columns]
#        time_difference
# count      4414.000000
# mean          7.167694
# std           4.553873
# min           1.000000
# 25%           4.000000
# 50%           7.000000
# 75%           9.700000
# max          22.700000

# %%
import pandas as pd
from pymongo import MongoClient

# Connect to the MongoDB server
client = MongoClient('mongodb://localhost:27017/')
db = client['EUA_db']
collection = db['events_data']

# Retrieve data from the collection
data = list(collection.find())

# Filter events for jobs
servers_events = [event for event in data if event['status'] in ['TypeEvent.server_switched_off', 'TypeEvent.server_switched_on']]

# Create jobs DataFrame
servers = pd.DataFrame(servers_events)
servers=servers[['origin_id','time','status']]


servers['id'] = 0
servers['type server'] = ''
for indx,row in servers.iterrows():
    msg = row['origin_id']
    servers.loc[indx,'id'] = msg.split(' ')[1]
    servers.loc[indx,'type server'] = msg.split(' ')[2]
    
display(servers)


# Assuming `jobs` DataFrame is already created and contains the necessary data

# Group by 'id' and sort by 'time' in reverse order
servers_sorted = servers.sort_values(by=['id', 'time'], ascending=[True, False])

# Initialize a list to store the results
time_differences = []

# Iterate over each group
for _, group in servers_sorted.groupby('id'):
    # Find the arrival time
    arrival_times = group[group['status'] == 'TypeEvent.server_switched_on']['time'].values
    if len(arrival_times) == 0:
        continue
    
    # Find the expired/completed time
    i=0
    for _, row in group.iterrows():
        if row['status'] in ['TypeEvent.server_switched_off']:
            arrival_time = float(arrival_times[i])        
            time_diff = float(row['time']) - arrival_time
            time_differences.append({
                'id': row['id'],
                'time_difference': time_diff,
                'type_server': row['type server']
            })
            i += 1

# Convert the results to a DataFrame
time_diff_df = pd.DataFrame(time_differences)
#display(time_diff_df)

summed_time_df = time_diff_df.groupby(['id','type_server']).sum('time_difference').reset_index()

# Rename the column for clarity
summed_time_df.rename(columns={'time_difference': 'total_time'}, inplace=True)

# Display the result
display(summed_time_df)
# Out:
# /tmp/ipykernel_44507/1464136998.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   servers.loc[indx,'id'] = msg.split(' ')[1]
#        origin_id  time                         status  id type server
# 0    Server 18 L    39   TypeEvent.server_switched_on  18           L
# 1    Server 11 L    40   TypeEvent.server_switched_on  11           L
# 2    Server 18 L    40  TypeEvent.server_switched_off  18           L
# 3    Server 11 L    41  TypeEvent.server_switched_off  11           L
# 4    Server 11 L    43   TypeEvent.server_switched_on  11           L
# ..           ...   ...                            ...  ..         ...
# 405  Server 29 L  1398   TypeEvent.server_switched_on  29           L
# 406   Server 3 L  1399  TypeEvent.server_switched_off   3           L
# 407  Server 29 L  1400  TypeEvent.server_switched_off  29           L
# 408   Server 3 L  1401   TypeEvent.server_switched_on   3           L
# 409   Server 3 L  1403  TypeEvent.server_switched_off   3           L
#
# [410 rows x 5 columns]
#     id type_server  total_time
# 0    0           L       224.0
# 1    1           L       494.0
# 2   10           L       376.0
# 3   11           L       325.0
# 4   12           L       454.0
# 5   13           L       345.0
# 6   14           L       316.0
# 7   15           L       406.0
# 8   16           L       486.0
# 9   17           L       438.0
# 10  18           L       569.0
# 11  19           L       630.0
# 12   2           L       382.0
# 13  20           L       754.0
# 14  21           L       316.0
# 15  22           L       263.0
# 16  23           L       362.0
# 17  24           L       593.0
# 18  25           L       528.0
# 19  26           L       364.0
# 20  27           L       457.0
# 21  28           L       434.0
# 22  29           L       338.0
# 23   3           L       476.0
# 24  30           L       431.0
# 25  31           L       373.0
# 26  32           L       430.0
# 27  33           L       361.0
# 28  34           L       667.0
# 29  35           L       375.0
# 30   4           L       505.0
# 31   5           L       420.0
# 32   6           L       426.0
# 33   7           L       382.0
# 34   8           L       362.0
# 35   9           L       532.0

# %%
import pandas as pd
from pymongo import MongoClient

# Connect to the MongoDB server
client = MongoClient('mongodb://localhost:27017/')
db = client['EUA_db']
collection = db['events_data']

# Retrieve data from the collection
data = list(collection.find())

# Filter events for jobs
job_events = [event for event in data if event['status'] in ['TypeEvent.user_arrival','TypeEvent.user_expired', 'TypeEvent.user_completed','TypeEvent.user_rejected_all_servers_out','TypeEvent.user_rejected_all_servers_off','TypeEvent.user_rejected_not_enough_time','TypeEvent.user_interrupted','TypeEvent.user_server_assigned','TypeEvent.server_going_to_process_user','TypeEvent.user_lock_for_resources','TypeEvent.user_unlock_for_resources','TypeEvent.user_rejected_not_enough_resources']]

# Create jobs DataFrame
jobs = pd.DataFrame(job_events)
jobs = jobs[['origin_id','time','status']]

jobs['id'] = -1
jobs['comp'] = -1
jobs["due"] = -1
for indx,row in jobs.iterrows():
    msg = row['origin_id']
    jobs.loc[indx,'id'] = msg.split(' ')[1]
    jobs.loc[indx,'comp'] = msg.split(' ')[4]
    jobs.loc[indx,'due'] = msg.split(' ')[5]

# Group by 'id' and sort by 'time' in reverse order
jobs['id']=jobs['id'].astype(int)
jobs['time'] = jobs['time'].astype(float)
jobs_sorted = jobs.sort_values(by=['id', 'time'], ascending=[True,True])

# Iterate over each group
event_jobs = []
for i, group in jobs_sorted.groupby('id'):
    event_jobs.append({'comp': [str(group['comp'].values[0])],'due': [str(group['due'].values[0])]})
    for _, row in group.iterrows():
        event = row['status'].replace('TypeEvent.','')
        if event not in event_jobs[-1]:
            event_jobs[-1][event] = []
        event_jobs[-1][event].append(str(row['time']))
        
    print(event_jobs[-1])

for job in event_jobs:
    for event in job:
        if len(job[event]) > 1:
            job[event] = ",".join(job[event])
        else:
            job[event] = str(job[event][0])

df = pd.DataFrame(event_jobs)

try:
    df = df[['comp', 'due', 'user_completed','user_arrival',
       'user_expired', 'user_server_assigned', 'user_lock_for_resources',
       'user_unlock_for_resources','user_rejected_not_enough_resources', 'user_rejected_not_enough_time','user_rejected_all_servers_out', 'user_interrupted']]
except Exception as e:
    print(e)

df.to_csv("events_jobs.csv")
# time_diff_df = pd.DataFrame(time_differences)
# 
# # Display the result
# display(time_diff_df)
# time_diff_df.describe()
# Out:
# /tmp/ipykernel_9497/2144648546.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   jobs.loc[indx,'id'] = msg.split(' ')[1]
# /tmp/ipykernel_9497/2144648546.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   jobs.loc[indx,'comp'] = msg.split(' ')[4]
# /tmp/ipykernel_9497/2144648546.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   jobs.loc[indx,'due'] = msg.split(' ')[5]
# {'comp': ['6'], 'due': ['17'], 'user_arrival': ['1.0'], 'user_rejected_all_servers_out': ['1.0', '3.0', '4.0', '6.0', '8.0', '11.0', '12.0', '14.0', '15.0', '18.0'], 'user_expired': ['18.0']}
# {'comp': ['5'], 'due': ['96'], 'user_arrival': ['78.0'], 'user_rejected_all_servers_out': ['78.0', '80.0', '82.0', '83.0', '85.0', '87.0', '90.0', '93.0', '95.0', '96.0'], 'user_expired': ['96.0']}
# {'comp': ['9'], 'due': ['206'], 'user_arrival': ['190.0'], 'user_server_assigned': ['190.0'], 'user_lock_for_resources': ['190.0'], 'user_unlock_for_resources': ['190.0'], 'user_completed': ['199.0', '199.0']}
# {'comp': ['8'], 'due': ['263'], 'user_arrival': ['249.0'], 'user_server_assigned': ['249.0'], 'user_lock_for_resources': ['249.0'], 'user_unlock_for_resources': ['249.0'], 'user_completed': ['257.0', '257.0']}
# {'comp': ['9'], 'due': ['269'], 'user_arrival': ['249.0'], 'user_rejected_all_servers_out': ['249.0', '251.0', '254.0', '256.0', '257.0', '258.0', '261.0', '264.0', '265.0', '266.0', '267.0', '269.0'], 'user_expired': ['269.0']}
# {'comp': ['6'], 'due': ['268'], 'user_arrival': ['250.0'], 'user_server_assigned': ['250.0'], 'user_lock_for_resources': ['250.0'], 'user_unlock_for_resources': ['250.0'], 'user_completed': ['256.0', '256.0']}
# {'comp': ['1'], 'due': ['261'], 'user_arrival': ['250.0'], 'user_server_assigned': ['250.0'], 'user_lock_for_resources': ['250.0'], 'user_unlock_for_resources': ['250.0'], 'user_completed': ['251.0', '251.0']}
# {'comp': ['7'], 'due': ['269'], 'user_arrival': ['250.0'], 'user_server_assigned': ['250.0'], 'user_lock_for_resources': ['250.0'], 'user_unlock_for_resources': ['250.0'], 'user_completed': ['257.0', '257.0']}
# {'comp': ['7'], 'due': ['267'], 'user_arrival': ['251.0'], 'user_server_assigned': ['251.0'], 'user_lock_for_resources': ['251.0'], 'user_unlock_for_resources': ['251.0'], 'user_completed': ['258.0', '258.0']}
# {'comp': ['4'], 'due': ['268'], 'user_arrival': ['251.0'], 'user_server_assigned': ['251.0'], 'user_lock_for_resources': ['251.0'], 'user_unlock_for_resources': ['251.0'], 'user_completed': ['255.0', '255.0']}
# {'comp': ['1'], 'due': ['272'], 'user_arrival': ['252.0'], 'user_server_assigned': ['252.0', '254.1', '256.2', '258.3', '260.40000000000003', '262.50000000000006', '264.6000000000001', '265.7000000000001', '268.8000000000001', '270.90000000000015', '272.00000000000017'], 'user_lock_for_resources': ['252.0', '254.1', '256.2', '258.3', '260.40000000000003', '262.50000000000006', '264.6000000000001', '265.7000000000001', '268.8000000000001', '270.90000000000015', '272.00000000000017'], 'user_unlock_for_resources': ['252.1', '254.2', '256.3', '258.40000000000003', '260.50000000000006', '262.6000000000001', '264.7000000000001', '265.8000000000001', '268.90000000000015', '271.00000000000017', '272.00000000000017'], 'user_rejected_not_enough_resources': ['252.1', '254.2', '256.3', '258.40000000000003', '260.50000000000006', '262.6000000000001', '264.7000000000001', '265.8000000000001', '268.90000000000015', '271.00000000000017'], 'user_rejected_not_enough_time': ['272.00000000000017'], 'user_expired': ['272.00000000000017']}
# {'comp': ['3'], 'due': ['264'], 'user_arrival': ['252.0'], 'user_server_assigned': ['252.0'], 'user_lock_for_resources': ['252.0'], 'user_unlock_for_resources': ['252.0'], 'user_completed': ['255.0', '255.0']}
# {'comp': ['8'], 'due': ['268'], 'user_arrival': ['252.0'], 'user_rejected_all_servers_out': ['252.0', '255.0', '257.0', '260.0', '262.0', '265.0', '268.0'], 'user_expired': ['268.0']}
# {'comp': ['1'], 'due': ['271'], 'user_arrival': ['252.0'], 'user_rejected_all_servers_out': ['252.0', '255.0', '258.0', '259.0', '261.0', '262.0', '264.0', '267.0', '269.0', '272.0'], 'user_expired': ['272.0']}
# {'comp': ['5'], 'due': ['269'], 'user_arrival': ['252.0'], 'user_server_assigned': ['252.0'], 'user_lock_for_resources': ['252.0'], 'user_unlock_for_resources': ['252.0'], 'user_completed': ['257.0', '257.0']}
# {'comp': ['1'], 'due': ['269'], 'user_arrival': ['252.0'], 'user_server_assigned': ['252.0', '253.1'], 'user_lock_for_resources': ['252.0', '253.1'], 'user_unlock_for_resources': ['252.1', '253.1'], 'user_rejected_not_enough_resources': ['252.1'], 'user_completed': ['254.1', '254.1']}
# {'comp': ['10'], 'due': ['263'], 'user_arrival': ['253.0'], 'user_rejected_all_servers_out': ['253.0', '255.0', '258.0', '259.0', '261.0', '264.0'], 'user_expired': ['264.0']}
# {'comp': ['8'], 'due': ['266'], 'user_arrival': ['253.0'], 'user_rejected_all_servers_out': ['253.0', '255.0', '256.0', '259.0', '262.0', '265.0', '268.0'], 'user_expired': ['268.0']}
# {'comp': ['8'], 'due': ['267'], 'user_arrival': ['253.0'], 'user_server_assigned': ['253.0'], 'user_lock_for_resources': ['253.0'], 'user_unlock_for_resources': ['253.0'], 'user_completed': ['261.0', '261.0']}
# {'comp': ['5'], 'due': ['267'], 'user_arrival': ['254.0'], 'user_server_assigned': ['254.0'], 'user_lock_for_resources': ['254.0'], 'user_unlock_for_resources': ['254.0'], 'user_completed': ['259.0', '259.0']}
# {'comp': ['3'], 'due': ['270'], 'user_arrival': ['255.0'], 'user_server_assigned': ['255.0'], 'user_lock_for_resources': ['255.0'], 'user_unlock_for_resources': ['255.0'], 'user_completed': ['258.0', '258.0']}
# {'comp': ['6'], 'due': ['275'], 'user_arrival': ['255.0'], 'user_server_assigned': ['255.0'], 'user_lock_for_resources': ['255.0'], 'user_unlock_for_resources': ['255.0'], 'user_completed': ['261.0', '261.0']}
# {'comp': ['4'], 'due': ['267'], 'user_arrival': ['256.0'], 'user_server_assigned': ['256.0'], 'user_lock_for_resources': ['256.0'], 'user_unlock_for_resources': ['256.0'], 'user_completed': ['260.0', '260.0']}
# {'comp': ['7'], 'due': ['275'], 'user_arrival': ['258.0'], 'user_server_assigned': ['258.0', '261.7', '263.4', '266.09999999999997', '269.79999999999995', '271.49999999999994', '274.19999999999993', '276.8999999999999'], 'user_lock_for_resources': ['258.0', '261.7', '263.4', '266.09999999999997', '269.79999999999995', '271.49999999999994', '274.19999999999993', '276.8999999999999'], 'user_unlock_for_resources': ['258.7', '262.4', '264.09999999999997', '266.79999999999995', '270.49999999999994', '272.19999999999993', '274.8999999999999', '276.8999999999999'], 'user_rejected_not_enough_resources': ['258.7', '262.4', '264.09999999999997', '266.79999999999995', '270.49999999999994', '272.19999999999993', '274.8999999999999'], 'user_rejected_not_enough_time': ['276.8999999999999'], 'user_expired': ['276.8999999999999']}
# {'comp': ['7'], 'due': ['277'], 'user_arrival': ['258.0'], 'user_server_assigned': ['258.0'], 'user_lock_for_resources': ['258.0'], 'user_unlock_for_resources': ['258.0'], 'user_completed': ['265.0', '265.0']}
# {'comp': ['6'], 'due': ['270'], 'user_arrival': ['258.0'], 'user_server_assigned': ['258.0'], 'user_lock_for_resources': ['258.0'], 'user_unlock_for_resources': ['258.0'], 'user_completed': ['264.0', '264.0']}
# {'comp': ['5'], 'due': ['272'], 'user_arrival': ['258.0'], 'user_server_assigned': ['258.0'], 'user_lock_for_resources': ['258.0'], 'user_unlock_for_resources': ['258.0'], 'user_completed': ['263.0', '263.0']}
# {'comp': ['7'], 'due': ['276'], 'user_arrival': ['259.0'], 'user_server_assigned': ['259.0'], 'user_lock_for_resources': ['259.0'], 'user_unlock_for_resources': ['259.0'], 'user_completed': ['266.0', '266.0']}
# {'comp': ['5'], 'due': ['273'], 'user_arrival': ['260.0'], 'user_server_assigned': ['260.0'], 'user_lock_for_resources': ['260.0'], 'user_unlock_for_resources': ['260.0'], 'user_completed': ['265.0', '265.0']}
# {'comp': ['5'], 'due': ['277'], 'user_arrival': ['260.0'], 'user_server_assigned': ['260.0', '262.5', '266.0', '268.5', '271.0', '272.5', '275.0', '276.5'], 'user_lock_for_resources': ['260.0', '262.5', '266.0', '268.5', '271.0', '272.5', '275.0', '276.5'], 'user_unlock_for_resources': ['260.5', '263.0', '266.5', '269.0', '271.5', '273.0', '275.5', '277.0'], 'user_rejected_not_enough_resources': ['260.5', '263.0', '266.5', '269.0', '271.5', '273.0', '275.5'], 'user_rejected_not_enough_time': ['277.0'], 'user_expired': ['277.0']}
# {'comp': ['1'], 'due': ['274'], 'user_arrival': ['262.0'], 'user_rejected_all_servers_out': ['262.0', '263.0', '266.0', '267.0', '270.0', '272.0', '273.0', '274.0'], 'user_expired': ['274.0']}
# {'comp': ['4'], 'due': ['278'], 'user_arrival': ['262.0'], 'user_server_assigned': ['262.0'], 'user_lock_for_resources': ['262.0'], 'user_unlock_for_resources': ['262.0'], 'user_completed': ['266.0', '266.0']}
# {'comp': ['9'], 'due': ['276'], 'user_arrival': ['262.0'], 'user_server_assigned': ['262.0', '263.9', '265.79999999999995', '268.69999999999993', '271.5999999999999', '275.4999999999999'], 'user_lock_for_resources': ['262.0', '263.9', '265.79999999999995', '268.69999999999993', '271.5999999999999', '275.4999999999999'], 'user_unlock_for_resources': ['262.9', '264.79999999999995', '266.69999999999993', '269.5999999999999', '272.4999999999999', '276.0'], 'user_rejected_not_enough_resources': ['262.9', '264.79999999999995', '266.69999999999993', '269.5999999999999', '272.4999999999999'], 'user_rejected_not_enough_time': ['276.0'], 'user_expired': ['276.0']}
# {'comp': ['3'], 'due': ['279'], 'user_arrival': ['262.0'], 'user_server_assigned': ['262.0', '265.3'], 'user_lock_for_resources': ['262.0', '265.3'], 'user_unlock_for_resources': ['262.3', '265.3'], 'user_rejected_not_enough_resources': ['262.3'], 'user_completed': ['268.3', '268.3']}
# {'comp': ['3'], 'due': ['279'], 'user_arrival': ['263.0'], 'user_rejected_all_servers_out': ['263.0', '264.0', '267.0', '270.0', '272.0', '275.0', '278.0', '281.0'], 'user_expired': ['281.0']}
# {'comp': ['7'], 'due': ['282'], 'user_arrival': ['264.0'], 'user_rejected_all_servers_out': ['264.0', '265.0', '266.0', '267.0', '270.0', '271.0', '273.0', '275.0', '277.0', '279.0', '280.0', '283.0'], 'user_expired': ['283.0']}
# {'comp': ['10'], 'due': ['277'], 'user_arrival': ['264.0'], 'user_server_assigned': ['264.0'], 'user_lock_for_resources': ['264.0'], 'user_unlock_for_resources': ['264.0'], 'user_completed': ['274.0', '274.0']}
# {'comp': ['5'], 'due': ['276'], 'user_arrival': ['264.0'], 'user_server_assigned': ['264.0', '267.5'], 'user_lock_for_resources': ['264.0', '267.5'], 'user_unlock_for_resources': ['264.5', '267.5'], 'user_rejected_not_enough_resources': ['264.5'], 'user_completed': ['272.5', '272.5']}
# {'comp': ['2'], 'due': ['285'], 'user_arrival': ['265.0'], 'user_server_assigned': ['265.0', '266.2', '268.4', '269.59999999999997', '271.79999999999995', '274.99999999999994', '278.19999999999993', '281.3999999999999', '284.5999999999999', '285.7999999999999'], 'user_lock_for_resources': ['265.0', '266.2', '268.4', '269.59999999999997', '271.79999999999995', '274.99999999999994', '278.19999999999993', '281.3999999999999', '284.5999999999999', '285.7999999999999'], 'user_unlock_for_resources': ['265.2', '266.4', '268.59999999999997', '269.79999999999995', '271.99999999999994', '275.19999999999993', '278.3999999999999', '281.5999999999999', '284.7999999999999', '285.7999999999999'], 'user_rejected_not_enough_resources': ['265.2', '266.4', '268.59999999999997', '269.79999999999995', '271.99999999999994', '275.19999999999993', '278.3999999999999', '281.5999999999999', '284.7999999999999'], 'user_rejected_not_enough_time': ['285.7999999999999'], 'user_expired': ['285.7999999999999']}
# {'comp': ['7'], 'due': ['278'], 'user_arrival': ['265.0'], 'user_server_assigned': ['265.0', '268.7'], 'user_lock_for_resources': ['265.0', '268.7'], 'user_unlock_for_resources': ['265.7', '268.7'], 'user_rejected_not_enough_resources': ['265.7'], 'user_completed': ['275.7', '275.7']}
# {'comp': ['3'], 'due': ['286'], 'user_arrival': ['266.0'], 'user_server_assigned': ['266.0', '267.3', '268.6', '271.90000000000003', '273.20000000000005', '275.50000000000006', '276.80000000000007', '280.1000000000001', '281.4000000000001', '284.7000000000001', '288.0000000000001'], 'user_lock_for_resources': ['266.0', '267.3', '268.6', '271.90000000000003', '273.20000000000005', '275.50000000000006', '276.80000000000007', '280.1000000000001', '281.4000000000001', '284.7000000000001', '288.0000000000001'], 'user_unlock_for_resources': ['266.3', '267.6', '268.90000000000003', '272.20000000000005', '273.50000000000006', '275.80000000000007', '277.1000000000001', '280.4000000000001', '281.7000000000001', '285.0000000000001', '288.0000000000001'], 'user_rejected_not_enough_resources': ['266.3', '267.6', '268.90000000000003', '272.20000000000005', '273.50000000000006', '275.80000000000007', '277.1000000000001', '280.4000000000001', '281.7000000000001', '285.0000000000001'], 'user_rejected_not_enough_time': ['288.0000000000001'], 'user_expired': ['288.0000000000001']}
# {'comp': ['8'], 'due': ['278'], 'user_arrival': ['266.0'], 'user_server_assigned': ['266.0'], 'user_lock_for_resources': ['266.0'], 'user_unlock_for_resources': ['266.0'], 'user_completed': ['274.0', '274.0']}
# {'comp': ['2'], 'due': ['281'], 'user_arrival': ['266.0'], 'user_server_assigned': ['266.0', '267.2'], 'user_lock_for_resources': ['266.0', '267.2'], 'user_unlock_for_resources': ['266.2', '267.2'], 'user_rejected_not_enough_resources': ['266.2'], 'user_completed': ['269.2', '269.2']}
# {'comp': ['4'], 'due': ['279'], 'user_arrival': ['267.0'], 'user_server_assigned': ['267.0', '270.4', '271.79999999999995', '274.19999999999993', '275.5999999999999', '276.9999999999999', '278.39999999999986', '280.79999999999984'], 'user_lock_for_resources': ['267.0', '270.4', '271.79999999999995', '274.19999999999993', '275.5999999999999', '276.9999999999999', '278.39999999999986', '280.79999999999984'], 'user_unlock_for_resources': ['267.4', '270.79999999999995', '272.19999999999993', '274.5999999999999', '275.9999999999999', '277.39999999999986', '278.79999999999984', '280.79999999999984'], 'user_rejected_not_enough_resources': ['267.4', '270.79999999999995', '272.19999999999993', '274.5999999999999', '275.9999999999999', '277.39999999999986', '278.79999999999984'], 'user_rejected_not_enough_time': ['280.79999999999984'], 'user_expired': ['280.79999999999984']}
# {'comp': ['8'], 'due': ['279'], 'user_arrival': ['269.0'], 'user_server_assigned': ['269.0'], 'user_lock_for_resources': ['269.0'], 'user_unlock_for_resources': ['269.0'], 'user_completed': ['277.0', '277.0']}
# {'comp': ['9'], 'due': ['288'], 'user_arrival': ['269.0'], 'user_server_assigned': ['269.0', '270.9'], 'user_lock_for_resources': ['269.0', '270.9'], 'user_unlock_for_resources': ['269.9', '270.9'], 'user_rejected_not_enough_resources': ['269.9'], 'user_completed': ['279.9', '279.9']}
# {'comp': ['9'], 'due': ['279'], 'user_arrival': ['269.0'], 'user_rejected_all_servers_out': ['269.0', '270.0', '273.0', '276.0', '277.0', '278.0'], 'user_server_assigned': ['279.0'], 'user_lock_for_resources': ['279.0'], 'user_unlock_for_resources': ['279.0'], 'user_rejected_not_enough_time': ['279.0'], 'user_expired': ['279.0']}
# {'comp': ['2'], 'due': ['279'], 'user_arrival': ['269.0'], 'user_rejected_all_servers_out': ['269.0', '270.0', '271.0', '273.0', '275.0', '276.0', '279.0'], 'user_expired': ['279.0']}
# {'comp': ['9'], 'due': ['281'], 'user_arrival': ['269.0'], 'user_server_assigned': ['269.0'], 'user_lock_for_resources': ['269.0'], 'user_unlock_for_resources': ['269.0'], 'user_completed': ['278.0', '278.0']}
# {'comp': ['4'], 'due': ['284'], 'user_arrival': ['270.0'], 'user_rejected_all_servers_out': ['270.0', '271.0', '274.0', '277.0', '280.0', '283.0', '286.0'], 'user_expired': ['286.0']}
# {'comp': ['2'], 'due': ['285'], 'user_arrival': ['270.0'], 'user_server_assigned': ['270.0'], 'user_lock_for_resources': ['270.0'], 'user_unlock_for_resources': ['270.0'], 'user_completed': ['272.0', '272.0']}
# {'comp': ['3'], 'due': ['285'], 'user_arrival': ['271.0'], 'user_server_assigned': ['271.0', '273.3', '275.6', '276.90000000000003', '278.20000000000005', '280.50000000000006', '283.80000000000007', '287.1000000000001'], 'user_lock_for_resources': ['271.0', '273.3', '275.6', '276.90000000000003', '278.20000000000005', '280.50000000000006', '283.80000000000007', '287.1000000000001'], 'user_unlock_for_resources': ['271.3', '273.6', '275.90000000000003', '277.20000000000005', '278.50000000000006', '280.80000000000007', '284.1000000000001', '287.1000000000001'], 'user_rejected_not_enough_resources': ['271.3', '273.6', '275.90000000000003', '277.20000000000005', '278.50000000000006', '280.80000000000007', '284.1000000000001'], 'user_rejected_not_enough_time': ['287.1000000000001'], 'user_expired': ['287.1000000000001']}
# {'comp': ['8'], 'due': ['291'], 'user_arrival': ['271.0'], 'user_server_assigned': ['271.0'], 'user_lock_for_resources': ['271.0'], 'user_unlock_for_resources': ['271.0'], 'user_completed': ['279.0', '279.0']}
# {'comp': ['3'], 'due': ['287'], 'user_arrival': ['271.0'], 'user_server_assigned': ['271.0', '274.3', '277.6', '278.90000000000003', '281.20000000000005', '283.50000000000006', '285.80000000000007', '289.1000000000001'], 'user_lock_for_resources': ['271.0', '274.3', '277.6', '278.90000000000003', '281.20000000000005', '283.50000000000006', '285.80000000000007', '289.1000000000001'], 'user_unlock_for_resources': ['271.3', '274.6', '277.90000000000003', '279.20000000000005', '281.50000000000006', '283.80000000000007', '286.1000000000001', '289.1000000000001'], 'user_rejected_not_enough_resources': ['271.3', '274.6', '277.90000000000003', '279.20000000000005', '281.50000000000006', '283.80000000000007', '286.1000000000001'], 'user_rejected_not_enough_time': ['289.1000000000001'], 'user_expired': ['289.1000000000001']}
# {'comp': ['1'], 'due': ['287'], 'user_arrival': ['272.0'], 'user_server_assigned': ['272.0', '275.1'], 'user_lock_for_resources': ['272.0', '275.1'], 'user_unlock_for_resources': ['272.1', '275.1'], 'user_rejected_not_enough_resources': ['272.1'], 'user_completed': ['276.1', '276.1']}
# {'comp': ['2'], 'due': ['288'], 'user_arrival': ['272.0'], 'user_server_assigned': ['272.0', '275.2'], 'user_lock_for_resources': ['272.0', '275.2'], 'user_unlock_for_resources': ['272.2', '275.2'], 'user_rejected_not_enough_resources': ['272.2'], 'user_completed': ['277.2', '277.2']}
# {'comp': ['10'], 'due': ['289'], 'user_arrival': ['272.0'], 'user_server_assigned': ['272.0'], 'user_lock_for_resources': ['272.0'], 'user_unlock_for_resources': ['272.0'], 'user_completed': ['282.0', '282.0']}
# {'comp': ['6'], 'due': ['288'], 'user_arrival': ['273.0'], 'user_server_assigned': ['273.0'], 'user_lock_for_resources': ['273.0'], 'user_unlock_for_resources': ['273.0'], 'user_completed': ['279.0', '279.0']}
# {'comp': ['8'], 'due': ['288'], 'user_arrival': ['273.0'], 'user_rejected_all_servers_out': ['273.0', '275.0', '276.0', '279.0', '280.0', '281.0', '282.0', '283.0', '284.0', '286.0', '287.0', '288.0'], 'user_expired': ['288.0']}
# {'comp': ['8'], 'due': ['288'], 'user_arrival': ['273.0'], 'user_server_assigned': ['273.0'], 'user_lock_for_resources': ['273.0'], 'user_unlock_for_resources': ['273.0'], 'user_completed': ['281.0', '281.0']}
# {'comp': ['10'], 'due': ['285'], 'user_arrival': ['274.0'], 'user_rejected_all_servers_out': ['274.0', '277.0', '278.0', '279.0', '282.0', '283.0', '286.0'], 'user_expired': ['286.0']}
# {'comp': ['5'], 'due': ['289'], 'user_arrival': ['274.0'], 'user_server_assigned': ['274.0'], 'user_lock_for_resources': ['274.0'], 'user_unlock_for_resources': ['274.0'], 'user_completed': ['279.0', '279.0']}
# {'comp': ['1'], 'due': ['295'], 'user_arrival': ['275.0'], 'user_server_assigned': ['275.0'], 'user_lock_for_resources': ['275.0'], 'user_unlock_for_resources': ['275.0'], 'user_completed': ['276.0', '276.0']}
# {'comp': ['6'], 'due': ['292'], 'user_arrival': ['276.0'], 'user_server_assigned': ['276.0'], 'user_lock_for_resources': ['276.0'], 'user_unlock_for_resources': ['276.5'], 'user_completed': ['282.5', '282.5']}
# {'comp': ['4'], 'due': ['293'], 'user_arrival': ['277.0'], 'user_server_assigned': ['277.0'], 'user_lock_for_resources': ['277.0'], 'user_unlock_for_resources': ['277.0'], 'user_completed': ['281.0', '281.0']}
# {'comp': ['10'], 'due': ['296'], 'user_arrival': ['278.0'], 'user_rejected_all_servers_out': ['278.0'], 'user_server_assigned': ['280.0', '281.0', '284.0', '286.0', '290.0', '294.0', '296.0'], 'user_lock_for_resources': ['280.0', '281.0', '284.0', '286.0', '290.0', '294.0', '296.0'], 'user_interrupted': ['280.0', '282.0', '285.0'], 'user_unlock_for_resources': ['287.0', '291.0', '295.0', '296.0'], 'user_rejected_not_enough_resources': ['287.0', '291.0', '295.0'], 'user_rejected_not_enough_time': ['296.0'], 'user_expired': ['296.0']}
# {'comp': ['8'], 'due': ['290'], 'user_arrival': ['278.0'], 'user_server_assigned': ['278.0'], 'user_lock_for_resources': ['278.0'], 'user_unlock_for_resources': ['278.0'], 'user_completed': ['286.0', '286.0']}
# {'comp': ['9'], 'due': ['294'], 'user_arrival': ['280.0'], 'user_server_assigned': ['280.0'], 'user_lock_for_resources': ['280.0'], 'user_unlock_for_resources': ['280.0'], 'user_completed': ['289.0', '289.0']}
# {'comp': ['3'], 'due': ['294'], 'user_arrival': ['281.0'], 'user_server_assigned': ['281.0'], 'user_lock_for_resources': ['281.0'], 'user_unlock_for_resources': ['281.0'], 'user_completed': ['284.0', '284.0']}
# {'comp': ['6'], 'due': ['292'], 'user_arrival': ['281.0'], 'user_rejected_all_servers_out': ['281.0', '282.0', '284.0', '285.0', '288.0', '289.0', '292.0'], 'user_expired': ['292.0']}
# {'comp': ['1'], 'due': ['291'], 'user_arrival': ['281.0'], 'user_server_assigned': ['281.0'], 'user_lock_for_resources': ['281.0'], 'user_unlock_for_resources': ['281.0'], 'user_completed': ['282.0', '282.0']}
# {'comp': ['4'], 'due': ['293'], 'user_arrival': ['281.0'], 'user_server_assigned': ['281.0', '283.4', '286.79999999999995', '288.19999999999993', '291.5999999999999', '294.9999999999999'], 'user_lock_for_resources': ['281.0', '283.4', '286.79999999999995', '288.19999999999993', '291.5999999999999', '294.9999999999999'], 'user_unlock_for_resources': ['281.4', '283.79999999999995', '287.19999999999993', '288.5999999999999', '291.9999999999999', '294.9999999999999'], 'user_rejected_not_enough_resources': ['281.4', '283.79999999999995', '287.19999999999993', '288.5999999999999', '291.9999999999999'], 'user_rejected_not_enough_time': ['294.9999999999999'], 'user_expired': ['294.9999999999999']}
# {'comp': ['3'], 'due': ['296'], 'user_arrival': ['283.0'], 'user_server_assigned': ['283.0'], 'user_lock_for_resources': ['283.0'], 'user_unlock_for_resources': ['283.0'], 'user_completed': ['286.0', '286.0']}
# {'comp': ['5'], 'due': ['295'], 'user_arrival': ['283.0'], 'user_server_assigned': ['283.0', '288.5', '290.0', '291.5', '293.0', '296.5'], 'user_lock_for_resources': ['283.0', '288.5', '290.0', '291.5', '293.0', '296.5'], 'user_unlock_for_resources': ['283.5', '289.0', '290.5', '292.0', '293.5', '296.5'], 'user_rejected_not_enough_resources': ['283.5', '289.0', '290.5', '292.0', '293.5'], 'user_rejected_all_servers_out': ['285.5'], 'user_rejected_not_enough_time': ['296.5'], 'user_expired': ['296.5']}
# {'comp': ['10'], 'due': ['294'], 'user_arrival': ['283.0'], 'user_server_assigned': ['283.0'], 'user_lock_for_resources': ['283.0'], 'user_unlock_for_resources': ['283.0'], 'user_completed': ['293.0', '293.0']}
# {'comp': ['4'], 'due': ['298'], 'user_arrival': ['284.0'], 'user_server_assigned': ['284.0'], 'user_lock_for_resources': ['284.0'], 'user_unlock_for_resources': ['284.0'], 'user_completed': ['288.0', '288.0']}
# {'comp': ['6'], 'due': ['299'], 'user_arrival': ['285.0'], 'user_server_assigned': ['285.0'], 'user_lock_for_resources': ['285.0'], 'user_unlock_for_resources': ['285.0'], 'user_completed': ['291.0', '291.0']}
# {'comp': ['6'], 'due': ['302'], 'user_arrival': ['287.0'], 'user_server_assigned': ['287.0', '289.6'], 'user_lock_for_resources': ['287.0', '289.6'], 'user_unlock_for_resources': ['287.6', '289.6'], 'user_rejected_not_enough_resources': ['287.6'], 'user_completed': ['295.6', '295.6']}
# {'comp': ['7'], 'due': ['302'], 'user_arrival': ['287.0'], 'user_rejected_all_servers_out': ['287.0', '289.0', '291.0', '294.0', '297.0', '300.0', '303.0'], 'user_expired': ['303.0']}
# {'comp': ['7'], 'due': ['300'], 'user_arrival': ['288.0'], 'user_server_assigned': ['288.0'], 'user_lock_for_resources': ['288.0'], 'user_unlock_for_resources': ['288.0'], 'user_completed': ['295.0', '295.0']}
# {'comp': ['9'], 'due': ['307'], 'user_arrival': ['289.0'], 'user_server_assigned': ['289.0', '293.0'], 'user_lock_for_resources': ['289.0', '293.0'], 'user_unlock_for_resources': ['289.0', '293.0'], 'user_interrupted': ['290.0'], 'user_completed': ['302.0', '302.0']}
# {'comp': ['6'], 'due': ['303'], 'user_arrival': ['289.0'], 'user_server_assigned': ['289.0'], 'user_lock_for_resources': ['289.0'], 'user_unlock_for_resources': ['289.0'], 'user_completed': ['295.0', '295.0']}
# {'comp': ['9'], 'due': ['300'], 'user_arrival': ['290.0'], 'user_server_assigned': ['290.0'], 'user_lock_for_resources': ['290.0'], 'user_unlock_for_resources': ['290.0'], 'user_completed': ['299.0', '299.0']}
# {'comp': ['10'], 'due': ['302'], 'user_arrival': ['290.0'], 'user_server_assigned': ['290.0', '292.0', '294.0', '296.0'], 'user_lock_for_resources': ['290.0', '292.0', '294.0', '296.0'], 'user_unlock_for_resources': ['291.0', '293.0', '295.0', '296.5'], 'user_rejected_not_enough_resources': ['291.0', '293.0', '295.0'], 'user_rejected_not_enough_time': ['302.0'], 'user_expired': ['302.0']}
# {'comp': ['6'], 'due': ['305'], 'user_arrival': ['290.0'], 'user_server_assigned': ['290.0'], 'user_lock_for_resources': ['290.0'], 'user_unlock_for_resources': ['290.0'], 'user_completed': ['296.0', '296.0']}
# {'comp': ['6'], 'due': ['303'], 'user_arrival': ['291.0'], 'user_server_assigned': ['291.0'], 'user_lock_for_resources': ['291.0'], 'user_unlock_for_resources': ['291.0'], 'user_completed': ['297.0', '297.0']}
# {'comp': ['3'], 'due': ['304'], 'user_arrival': ['292.0'], 'user_server_assigned': ['292.0'], 'user_lock_for_resources': ['292.0'], 'user_unlock_for_resources': ['292.0'], 'user_completed': ['295.0', '295.0']}
# {'comp': ['10'], 'due': ['305'], 'user_arrival': ['293.0'], 'user_rejected_all_servers_out': ['293.0', '294.0', '295.0', '297.0', '299.0', '302.0', '305.0'], 'user_expired': ['305.0']}
# {'comp': ['6'], 'due': ['311'], 'user_arrival': ['294.0'], 'user_server_assigned': ['294.0'], 'user_lock_for_resources': ['294.0'], 'user_unlock_for_resources': ['294.0'], 'user_completed': ['300.0', '300.0']}
# {'comp': ['7'], 'due': ['307'], 'user_arrival': ['294.0'], 'user_server_assigned': ['294.0'], 'user_lock_for_resources': ['294.0'], 'user_unlock_for_resources': ['294.0'], 'user_completed': ['301.0', '301.0']}
# {'comp': ['10'], 'due': ['306'], 'user_arrival': ['294.0'], 'user_server_assigned': ['294.0'], 'user_lock_for_resources': ['294.0'], 'user_unlock_for_resources': ['294.0'], 'user_completed': ['304.0', '304.0']}
# {'comp': ['3'], 'due': ['309'], 'user_arrival': ['295.0'], 'user_server_assigned': ['295.0'], 'user_lock_for_resources': ['295.0'], 'user_unlock_for_resources': ['295.0'], 'user_completed': ['298.0', '298.0']}
# {'comp': ['6'], 'due': ['309'], 'user_arrival': ['296.0'], 'user_server_assigned': ['296.0'], 'user_lock_for_resources': ['296.0'], 'user_unlock_for_resources': ['296.0'], 'user_completed': ['302.0', '302.0']}
# {'comp': ['7'], 'due': ['312'], 'user_arrival': ['298.0'], 'user_server_assigned': ['298.0'], 'user_lock_for_resources': ['298.0'], 'user_unlock_for_resources': ['298.0'], 'user_completed': ['305.0', '305.0']}
# {'comp': ['10'], 'due': ['310'], 'user_arrival': ['298.0'], 'user_server_assigned': ['298.0'], 'user_lock_for_resources': ['298.0'], 'user_unlock_for_resources': ['298.0'], 'user_completed': ['308.0', '308.0']}
# {'comp': ['9'], 'due': ['311'], 'user_arrival': ['298.0'], 'user_server_assigned': ['298.0'], 'user_lock_for_resources': ['298.0'], 'user_unlock_for_resources': ['298.0'], 'user_completed': ['307.0', '307.0']}
# {'comp': ['8'], 'due': ['317'], 'user_arrival': ['299.0'], 'user_server_assigned': ['299.0'], 'user_lock_for_resources': ['299.0'], 'user_unlock_for_resources': ['299.0'], 'user_completed': ['307.0', '307.0']}
# {'comp': ['1'], 'due': ['318'], 'user_arrival': ['299.0'], 'user_server_assigned': ['299.0'], 'user_lock_for_resources': ['299.0'], 'user_unlock_for_resources': ['299.0'], 'user_completed': ['300.0', '300.0']}
# {'comp': ['7'], 'due': ['312'], 'user_arrival': ['299.0'], 'user_server_assigned': ['299.0'], 'user_lock_for_resources': ['299.0'], 'user_unlock_for_resources': ['299.0'], 'user_completed': ['306.0', '306.0']}
# {'comp': ['3'], 'due': ['309'], 'user_arrival': ['299.0'], 'user_server_assigned': ['299.0', '300.3', '303.6', '304.90000000000003', '306.20000000000005', '308.50000000000006', '310.80000000000007'], 'user_lock_for_resources': ['299.0', '300.3', '303.6', '304.90000000000003', '306.20000000000005', '308.50000000000006', '310.80000000000007'], 'user_unlock_for_resources': ['299.3', '300.6', '303.90000000000003', '305.20000000000005', '306.50000000000006', '308.80000000000007', '310.80000000000007'], 'user_rejected_not_enough_resources': ['299.3', '300.6', '303.90000000000003', '305.20000000000005', '306.50000000000006', '308.80000000000007'], 'user_rejected_not_enough_time': ['310.80000000000007'], 'user_expired': ['310.80000000000007']}
# {'comp': ['1'], 'due': ['318'], 'user_arrival': ['299.0'], 'user_rejected_all_servers_out': ['299.0', '301.0', '304.0', '305.0', '307.0', '309.0', '310.0', '313.0', '314.0', '316.0', '319.0'], 'user_expired': ['319.0']}
# {'comp': ['2'], 'due': ['319'], 'user_arrival': ['299.0'], 'user_rejected_all_servers_out': ['299.0', '301.0', '304.0', '305.0', '307.0', '308.0', '309.0', '311.0', '314.0', '316.0', '319.0'], 'user_expired': ['319.0']}
# {'comp': ['9'], 'due': ['310'], 'user_arrival': ['299.0'], 'user_server_assigned': ['299.0'], 'user_lock_for_resources': ['299.0'], 'user_unlock_for_resources': ['299.0'], 'user_completed': ['308.0', '308.0']}
# {'comp': ['1'], 'due': ['313'], 'user_arrival': ['300.0'], 'user_server_assigned': ['300.0'], 'user_lock_for_resources': ['300.0'], 'user_unlock_for_resources': ['300.0'], 'user_completed': ['301.0', '301.0']}
# {'comp': ['10'], 'due': ['316'], 'user_arrival': ['300.0'], 'user_server_assigned': ['300.0', '302.0', '305.0', '307.0'], 'user_lock_for_resources': ['300.0', '302.0', '305.0', '307.0'], 'user_unlock_for_resources': ['301.0', '303.0', '306.0', '307.0'], 'user_rejected_not_enough_resources': ['301.0', '303.0', '306.0'], 'user_rejected_not_enough_time': ['316.0'], 'user_expired': ['316.0']}
# {'comp': ['9'], 'due': ['314'], 'user_arrival': ['300.0'], 'user_server_assigned': ['300.0'], 'user_lock_for_resources': ['300.0'], 'user_unlock_for_resources': ['300.0'], 'user_completed': ['309.0', '309.0']}
# {'comp': ['8'], 'due': ['318'], 'user_arrival': ['300.0'], 'user_server_assigned': ['300.0'], 'user_lock_for_resources': ['300.0'], 'user_unlock_for_resources': ['300.0'], 'user_completed': ['308.0', '308.0']}
# {'comp': ['6'], 'due': ['317'], 'user_arrival': ['300.0'], 'user_server_assigned': ['300.0'], 'user_lock_for_resources': ['300.0'], 'user_unlock_for_resources': ['300.0'], 'user_completed': ['306.0', '306.0']}
# {'comp': ['8'], 'due': ['316'], 'user_arrival': ['301.0'], 'user_server_assigned': ['301.0'], 'user_lock_for_resources': ['301.0'], 'user_unlock_for_resources': ['301.0'], 'user_completed': ['309.0', '309.0']}
# {'comp': ['5'], 'due': ['318'], 'user_arrival': ['301.0'], 'user_server_assigned': ['301.0'], 'user_lock_for_resources': ['301.0'], 'user_unlock_for_resources': ['301.0'], 'user_completed': ['306.0', '306.0']}
# {'comp': ['2'], 'due': ['312'], 'user_arrival': ['302.0'], 'user_server_assigned': ['302.0'], 'user_lock_for_resources': ['302.0'], 'user_unlock_for_resources': ['302.0'], 'user_completed': ['304.0', '304.0']}
# {'comp': ['4'], 'due': ['312'], 'user_arrival': ['302.0'], 'user_server_assigned': ['302.0', '304.4', '306.79999999999995'], 'user_lock_for_resources': ['302.0', '304.4', '306.79999999999995'], 'user_unlock_for_resources': ['302.4', '304.79999999999995', '306.79999999999995'], 'user_rejected_not_enough_resources': ['302.4', '304.79999999999995'], 'user_completed': ['310.79999999999995', '310.79999999999995']}
# {'comp': ['6'], 'due': ['316'], 'user_arrival': ['302.0'], 'user_rejected_all_servers_out': ['302.0', '304.0', '307.0', '309.0', '312.0', '314.0', '316.0'], 'user_expired': ['316.0']}
# {'comp': ['3'], 'due': ['315'], 'user_arrival': ['302.0'], 'user_server_assigned': ['302.0', '305.3', '306.6'], 'user_lock_for_resources': ['302.0', '305.3', '306.6'], 'user_unlock_for_resources': ['302.3', '305.6', '306.6'], 'user_rejected_not_enough_resources': ['302.3', '305.6'], 'user_completed': ['309.6', '309.6']}
# {'comp': ['8'], 'due': ['321'], 'user_arrival': ['303.0'], 'user_server_assigned': ['303.0'], 'user_lock_for_resources': ['303.0'], 'user_unlock_for_resources': ['303.0'], 'user_completed': ['311.0', '311.0']}
# {'comp': ['2'], 'due': ['319'], 'user_arrival': ['303.0'], 'user_server_assigned': ['303.0', '304.2', '306.4', '309.59999999999997'], 'user_lock_for_resources': ['303.0', '304.2', '306.4', '309.59999999999997'], 'user_unlock_for_resources': ['303.2', '304.4', '306.59999999999997', '309.59999999999997'], 'user_rejected_not_enough_resources': ['303.2', '304.4', '306.59999999999997'], 'user_completed': ['311.59999999999997', '311.59999999999997']}
# {'comp': ['6'], 'due': ['314'], 'user_arrival': ['304.0'], 'user_server_assigned': ['304.0'], 'user_lock_for_resources': ['304.0'], 'user_unlock_for_resources': ['304.0'], 'user_completed': ['310.0', '310.0']}
# {'comp': ['7'], 'due': ['324'], 'user_arrival': ['304.0'], 'user_rejected_all_servers_out': ['304.0', '307.0', '308.0', '309.0', '310.0', '311.0', '314.0', '317.0', '320.0', '321.0', '323.0', '324.0'], 'user_expired': ['324.0']}
# {'comp': ['10'], 'due': ['321'], 'user_arrival': ['304.0'], 'user_rejected_all_servers_out': ['304.0', '307.0', '310.0', '313.0', '316.0', '317.0', '319.0', '320.0', '323.0'], 'user_expired': ['323.0']}
# {'comp': ['1'], 'due': ['318'], 'user_arrival': ['304.0'], 'user_rejected_all_servers_out': ['304.0', '306.0', '309.0', '310.0', '312.0', '315.0', '317.0', '318.0'], 'user_expired': ['318.0']}
# {'comp': ['4'], 'due': ['322'], 'user_arrival': ['304.0'], 'user_server_assigned': ['304.0'], 'user_lock_for_resources': ['304.0'], 'user_unlock_for_resources': ['304.0'], 'user_completed': ['308.0', '308.0']}
# {'comp': ['5'], 'due': ['316'], 'user_arrival': ['305.0'], 'user_server_assigned': ['305.0', '308.5', '310.0'], 'user_lock_for_resources': ['305.0', '308.5', '310.0'], 'user_unlock_for_resources': ['305.5', '309.0', '310.0'], 'user_rejected_not_enough_resources': ['305.5', '309.0'], 'user_completed': ['315.0', '315.0']}
# {'comp': ['4'], 'due': ['325'], 'user_arrival': ['305.0'], 'user_server_assigned': ['305.0', '308.4', '310.79999999999995', '314.19999999999993', '316.5999999999999', '317.9999999999999', '321.39999999999986', '323.79999999999984', '327.1999999999998'], 'user_lock_for_resources': ['305.0', '308.4', '310.79999999999995', '314.19999999999993', '316.5999999999999', '317.9999999999999', '321.39999999999986', '323.79999999999984', '327.1999999999998'], 'user_unlock_for_resources': ['305.4', '308.79999999999995', '311.19999999999993', '314.5999999999999', '316.9999999999999', '318.39999999999986', '321.79999999999984', '324.1999999999998', '327.1999999999998'], 'user_rejected_not_enough_resources': ['305.4', '308.79999999999995', '311.19999999999993', '314.5999999999999', '316.9999999999999', '318.39999999999986', '321.79999999999984', '324.1999999999998'], 'user_rejected_not_enough_time': ['327.1999999999998'], 'user_expired': ['327.1999999999998']}
# {'comp': ['7'], 'due': ['324'], 'user_arrival': ['305.0'], 'user_server_assigned': ['305.0', '308.7', '311.4'], 'user_lock_for_resources': ['305.0', '308.7', '311.4'], 'user_unlock_for_resources': ['305.7', '309.4', '311.4'], 'user_rejected_not_enough_resources': ['305.7', '309.4'], 'user_completed': ['318.4', '318.4']}
# {'comp': ['8'], 'due': ['324'], 'user_arrival': ['305.0'], 'user_server_assigned': ['305.0', '306.8', '309.6'], 'user_lock_for_resources': ['305.0', '306.8', '309.6'], 'user_unlock_for_resources': ['305.8', '307.6', '309.6'], 'user_rejected_not_enough_resources': ['305.8', '307.6'], 'user_completed': ['317.6', '317.6']}
# {'comp': ['7'], 'due': ['322'], 'user_arrival': ['305.0'], 'user_rejected_all_servers_out': ['305.0', '308.0', '309.0', '310.0', '313.0', '314.0', '315.0', '316.0', '318.0', '320.0', '321.0', '324.0'], 'user_expired': ['324.0']}
# {'comp': ['4'], 'due': ['321'], 'user_arrival': ['306.0'], 'user_server_assigned': ['306.0'], 'user_lock_for_resources': ['306.0'], 'user_unlock_for_resources': ['306.0'], 'user_completed': ['310.0', '310.0']}
# {'comp': ['6'], 'due': ['319'], 'user_arrival': ['306.0'], 'user_server_assigned': ['306.0', '309.6'], 'user_lock_for_resources': ['306.0', '309.6'], 'user_unlock_for_resources': ['306.6', '309.6'], 'user_rejected_not_enough_resources': ['306.6'], 'user_completed': ['315.6', '315.6']}
# {'comp': ['5'], 'due': ['323'], 'user_arrival': ['307.0'], 'user_server_assigned': ['307.0', '308.5', '312.0', '315.5', '317.0', '318.5', '321.0', '324.5'], 'user_lock_for_resources': ['307.0', '308.5', '312.0', '315.5', '317.0', '318.5', '321.0', '324.5'], 'user_unlock_for_resources': ['307.5', '309.0', '312.5', '316.0', '317.5', '319.0', '321.5', '324.5'], 'user_rejected_not_enough_resources': ['307.5', '309.0', '312.5', '316.0', '317.5', '319.0', '321.5'], 'user_rejected_not_enough_time': ['324.5'], 'user_expired': ['324.5']}
# {'comp': ['9'], 'due': ['324'], 'user_arrival': ['307.0'], 'user_server_assigned': ['307.0', '310.9'], 'user_lock_for_resources': ['307.0', '310.9'], 'user_unlock_for_resources': ['307.9', '310.9'], 'user_rejected_not_enough_resources': ['307.9'], 'user_completed': ['319.9', '319.9']}
# {'comp': ['9'], 'due': ['325'], 'user_arrival': ['307.0'], 'user_server_assigned': ['307.0', '310.9'], 'user_lock_for_resources': ['307.0', '310.9'], 'user_unlock_for_resources': ['307.9', '310.9'], 'user_rejected_not_enough_resources': ['307.9'], 'user_completed': ['319.9', '319.9']}
# {'comp': ['1'], 'due': ['320'], 'user_arrival': ['307.0'], 'user_server_assigned': ['307.0'], 'user_lock_for_resources': ['307.0'], 'user_unlock_for_resources': ['307.0'], 'user_completed': ['308.0', '308.0']}
# {'comp': ['8'], 'due': ['323'], 'user_arrival': ['308.0'], 'user_server_assigned': ['308.0'], 'user_lock_for_resources': ['308.0'], 'user_unlock_for_resources': ['308.0'], 'user_completed': ['316.0', '316.0']}
# {'comp': ['6'], 'due': ['326'], 'user_arrival': ['309.0'], 'user_server_assigned': ['309.0'], 'user_lock_for_resources': ['309.0'], 'user_unlock_for_resources': ['309.0'], 'user_completed': ['315.0', '315.0']}
# {'comp': ['9'], 'due': ['326'], 'user_arrival': ['309.0'], 'user_rejected_all_servers_out': ['309.0', '311.0', '314.0', '317.0', '319.0', '320.0', '321.0', '324.0', '325.0', '326.0'], 'user_expired': ['326.0']}
# {'comp': ['6'], 'due': ['325'], 'user_arrival': ['310.0'], 'user_server_assigned': ['310.0'], 'user_lock_for_resources': ['310.0'], 'user_unlock_for_resources': ['310.0'], 'user_completed': ['316.0', '316.0']}
# {'comp': ['9'], 'due': ['331'], 'user_arrival': ['311.0'], 'user_server_assigned': ['311.0'], 'user_lock_for_resources': ['311.0'], 'user_unlock_for_resources': ['311.0'], 'user_completed': ['320.0', '320.0']}
# {'comp': ['8'], 'due': ['332'], 'user_arrival': ['312.0'], 'user_server_assigned': ['312.0'], 'user_lock_for_resources': ['312.0'], 'user_unlock_for_resources': ['312.0'], 'user_completed': ['320.0', '320.0']}
# {'comp': ['7'], 'due': ['331'], 'user_arrival': ['314.0'], 'user_server_assigned': ['314.0'], 'user_lock_for_resources': ['314.0'], 'user_unlock_for_resources': ['314.0'], 'user_completed': ['321.0', '321.0']}
# {'comp': ['4'], 'due': ['327'], 'user_arrival': ['314.0'], 'user_server_assigned': ['314.0'], 'user_lock_for_resources': ['314.0'], 'user_unlock_for_resources': ['314.0'], 'user_completed': ['318.0', '318.0']}
# {'comp': ['5'], 'due': ['333'], 'user_arrival': ['314.0'], 'user_server_assigned': ['314.0'], 'user_lock_for_resources': ['314.0'], 'user_unlock_for_resources': ['314.0'], 'user_completed': ['319.0', '319.0']}
# {'comp': ['1'], 'due': ['327'], 'user_arrival': ['315.0'], 'user_server_assigned': ['315.0'], 'user_lock_for_resources': ['315.0'], 'user_unlock_for_resources': ['315.0'], 'user_completed': ['316.0', '316.0']}
# {'comp': ['3'], 'due': ['335'], 'user_arrival': ['315.0'], 'user_server_assigned': ['315.0', '317.3', '318.6', '321.90000000000003', '324.20000000000005', '325.50000000000006', '327.80000000000007', '330.1000000000001', '332.4000000000001', '333.7000000000001', '337.0000000000001'], 'user_lock_for_resources': ['315.0', '317.3', '318.6', '321.90000000000003', '324.20000000000005', '325.50000000000006', '327.80000000000007', '330.1000000000001', '332.4000000000001', '333.7000000000001', '337.0000000000001'], 'user_unlock_for_resources': ['315.3', '317.6', '318.90000000000003', '322.20000000000005', '324.50000000000006', '325.80000000000007', '328.1000000000001', '330.4000000000001', '332.7000000000001', '334.0000000000001', '337.0000000000001'], 'user_rejected_not_enough_resources': ['315.3', '317.6', '318.90000000000003', '322.20000000000005', '324.50000000000006', '325.80000000000007', '328.1000000000001', '330.4000000000001', '332.7000000000001', '334.0000000000001'], 'user_rejected_not_enough_time': ['337.0000000000001'], 'user_expired': ['337.0000000000001']}
# {'comp': ['1'], 'due': ['332'], 'user_arrival': ['316.0'], 'user_server_assigned': ['316.0'], 'user_lock_for_resources': ['316.0'], 'user_unlock_for_resources': ['316.0'], 'user_completed': ['317.0', '317.0']}
# {'comp': ['5'], 'due': ['327'], 'user_arrival': ['316.0'], 'user_rejected_all_servers_out': ['316.0', '318.0', '319.0', '322.0', '324.0', '325.0', '327.0'], 'user_expired': ['327.0']}
# {'comp': ['4'], 'due': ['330'], 'user_arrival': ['316.0'], 'user_server_assigned': ['316.0'], 'user_lock_for_resources': ['316.0'], 'user_unlock_for_resources': ['316.0'], 'user_completed': ['320.0', '320.0']}
# {'comp': ['4'], 'due': ['337'], 'user_arrival': ['317.0'], 'user_rejected_all_servers_out': ['317.0', '320.0', '321.0', '324.0', '327.0', '328.0', '331.0', '334.0', '336.0', '337.0'], 'user_expired': ['337.0']}
# {'comp': ['3'], 'due': ['336'], 'user_arrival': ['317.0'], 'user_server_assigned': ['317.0'], 'user_lock_for_resources': ['317.0'], 'user_unlock_for_resources': ['317.0'], 'user_completed': ['320.0', '320.0']}
# {'comp': ['2'], 'due': ['337'], 'user_arrival': ['317.0'], 'user_server_assigned': ['317.0'], 'user_lock_for_resources': ['317.0'], 'user_unlock_for_resources': ['317.0'], 'user_completed': ['319.0', '319.0']}
# {'comp': ['4'], 'due': ['332'], 'user_arrival': ['318.0'], 'user_server_assigned': ['318.0'], 'user_lock_for_resources': ['318.0'], 'user_unlock_for_resources': ['318.0'], 'user_completed': ['322.0', '322.0']}
# {'comp': ['3'], 'due': ['337'], 'user_arrival': ['319.0'], 'user_server_assigned': ['319.0'], 'user_lock_for_resources': ['319.0'], 'user_unlock_for_resources': ['319.0'], 'user_completed': ['322.0', '322.0']}
# {'comp': ['10'], 'due': ['332'], 'user_arrival': ['319.0'], 'user_server_assigned': ['319.0'], 'user_lock_for_resources': ['319.0'], 'user_unlock_for_resources': ['319.0'], 'user_completed': ['329.0', '329.0']}
# {'comp': ['7'], 'due': ['330'], 'user_arrival': ['320.0'], 'user_server_assigned': ['320.0'], 'user_lock_for_resources': ['320.0'], 'user_unlock_for_resources': ['320.0'], 'user_completed': ['327.0', '327.0']}
# {'comp': ['3'], 'due': ['339'], 'user_arrival': ['320.0'], 'user_server_assigned': ['320.0'], 'user_lock_for_resources': ['320.0'], 'user_unlock_for_resources': ['320.0'], 'user_completed': ['323.0', '323.0']}
# {'comp': ['2'], 'due': ['339'], 'user_arrival': ['320.0'], 'user_server_assigned': ['320.0'], 'user_lock_for_resources': ['320.0'], 'user_unlock_for_resources': ['320.0'], 'user_completed': ['322.0', '322.0']}
# {'comp': ['1'], 'due': ['343'], 'user_arrival': ['323.0'], 'user_rejected_all_servers_out': ['323.0', '324.0', '327.0', '330.0', '332.0', '334.0', '337.0', '339.0', '340.0', '341.0', '343.0'], 'user_expired': ['343.0']}
# {'comp': ['8'], 'due': ['334'], 'user_arrival': ['323.0'], 'user_rejected_all_servers_out': ['323.0', '326.0', '329.0', '332.0', '335.0'], 'user_expired': ['335.0']}
# {'comp': ['1'], 'due': ['342'], 'user_arrival': ['324.0'], 'user_server_assigned': ['324.0', '326.1', '327.20000000000005', '330.30000000000007', '333.4000000000001', '335.5000000000001', '337.60000000000014', '339.70000000000016', '340.8000000000002', '343.9000000000002'], 'user_lock_for_resources': ['324.0', '326.1', '327.20000000000005', '330.30000000000007', '333.4000000000001', '335.5000000000001', '337.60000000000014', '339.70000000000016', '340.8000000000002', '343.9000000000002'], 'user_unlock_for_resources': ['324.1', '326.20000000000005', '327.30000000000007', '330.4000000000001', '333.5000000000001', '335.60000000000014', '337.70000000000016', '339.8000000000002', '340.9000000000002', '343.9000000000002'], 'user_rejected_not_enough_resources': ['324.1', '326.20000000000005', '327.30000000000007', '330.4000000000001', '333.5000000000001', '335.60000000000014', '337.70000000000016', '339.8000000000002', '340.9000000000002'], 'user_rejected_not_enough_time': ['343.9000000000002'], 'user_expired': ['343.9000000000002']}
# {'comp': ['4'], 'due': ['345'], 'user_arrival': ['325.0'], 'user_server_assigned': ['325.0'], 'user_lock_for_resources': ['325.0'], 'user_unlock_for_resources': ['325.0'], 'user_completed': ['329.0', '329.0']}
# {'comp': ['6'], 'due': ['335'], 'user_arrival': ['325.0'], 'user_server_assigned': ['325.0'], 'user_lock_for_resources': ['325.0'], 'user_unlock_for_resources': ['325.0'], 'user_completed': ['331.0', '331.0']}
# {'comp': ['10'], 'due': ['344'], 'user_arrival': ['325.0'], 'user_server_assigned': ['325.0', '327.0', '331.0', '334.0', '338.0', '340.0', '344.0'], 'user_lock_for_resources': ['325.0', '327.0', '331.0', '334.0', '338.0', '340.0', '344.0'], 'user_unlock_for_resources': ['326.0', '328.0', '332.0', '335.0', '339.0', '341.0', '344.0'], 'user_rejected_not_enough_resources': ['326.0', '328.0', '332.0', '335.0', '339.0', '341.0'], 'user_rejected_not_enough_time': ['344.0'], 'user_expired': ['344.0']}
# {'comp': ['10'], 'due': ['336'], 'user_arrival': ['325.0'], 'user_server_assigned': ['325.0', '328.0', '330.0', '333.0', '335.0'], 'user_lock_for_resources': ['325.0', '328.0', '330.0', '333.0', '335.0'], 'user_unlock_for_resources': ['326.0', '329.0', '331.0', '334.0', '336.0'], 'user_rejected_not_enough_resources': ['326.0', '329.0', '331.0', '334.0'], 'user_rejected_not_enough_time': ['336.0'], 'user_expired': ['336.0']}
# {'comp': ['7'], 'due': ['336'], 'user_arrival': ['326.0'], 'user_rejected_all_servers_out': ['326.0', '328.0', '330.0', '331.0', '334.0', '336.0'], 'user_expired': ['336.0']}
# ...
# {'comp': ['5'], 'due': ['1093'], 'user_arrival': ['1079.0'], 'user_server_assigned': ['1079.0'], 'user_lock_for_resources': ['1079.0'], 'user_unlock_for_resources': ['1079.0'], 'user_completed': ['1084.0', '1084.0']}
# {'comp': ['7'], 'due': ['1096'], 'user_arrival': ['1080.0'], 'user_server_assigned': ['1080.0'], 'user_lock_for_resources': ['1080.0'], 'user_unlock_for_resources': ['1080.0'], 'user_completed': ['1087.0', '1087.0']}
# {'comp': ['7'], 'due': ['1097'], 'user_arrival': ['1080.0'], 'user_server_assigned': ['1080.0', '1081.7', '1084.4', '1086.1000000000001', '1087.8000000000002', '1091.5000000000002', '1095.2000000000003', '1096.9000000000003'], 'user_lock_for_resources': ['1080.0', '1081.7', '1084.4', '1086.1000000000001', '1087.8000000000002', '1091.5000000000002', '1095.2000000000003', '1096.9000000000003'], 'user_unlock_for_resources': ['1080.7', '1082.4', '1085.1000000000001', '1086.8000000000002', '1088.5000000000002', '1092.2000000000003', '1095.9000000000003', '1097.0'], 'user_rejected_not_enough_resources': ['1080.7', '1082.4', '1085.1000000000001', '1086.8000000000002', '1088.5000000000002', '1092.2000000000003', '1095.9000000000003'], 'user_rejected_not_enough_time': ['1097.0'], 'user_expired': ['1097.0']}
# {'comp': ['8'], 'due': ['1090'], 'user_arrival': ['1080.0'], 'user_server_assigned': ['1080.0'], 'user_lock_for_resources': ['1080.0'], 'user_unlock_for_resources': ['1080.0'], 'user_completed': ['1088.0', '1088.0']}
# {'comp': ['3'], 'due': ['1098'], 'user_arrival': ['1081.0'], 'user_server_assigned': ['1081.0', '1082.3'], 'user_lock_for_resources': ['1081.0', '1082.3'], 'user_unlock_for_resources': ['1081.3', '1082.3'], 'user_rejected_not_enough_resources': ['1081.3'], 'user_completed': ['1085.3', '1085.3']}
# {'comp': ['9'], 'due': ['1097'], 'user_arrival': ['1081.0'], 'user_server_assigned': ['1081.0'], 'user_lock_for_resources': ['1081.0'], 'user_unlock_for_resources': ['1081.0'], 'user_completed': ['1090.0', '1090.0']}
# {'comp': ['7'], 'due': ['1095'], 'user_arrival': ['1081.0'], 'user_server_assigned': ['1081.0'], 'user_lock_for_resources': ['1081.0'], 'user_unlock_for_resources': ['1081.0'], 'user_completed': ['1088.0', '1088.0']}
# {'comp': ['5'], 'due': ['1102'], 'user_arrival': ['1083.0'], 'user_server_assigned': ['1083.0'], 'user_lock_for_resources': ['1083.0'], 'user_unlock_for_resources': ['1083.0'], 'user_completed': ['1088.0', '1088.0']}
# {'comp': ['1'], 'due': ['1101'], 'user_arrival': ['1083.0'], 'user_rejected_all_servers_out': ['1083.0', '1085.0', '1087.0', '1090.0', '1092.0', '1095.0', '1097.0', '1100.0', '1103.0'], 'user_expired': ['1103.0']}
# {'comp': ['8'], 'due': ['1104'], 'user_arrival': ['1084.0'], 'user_server_assigned': ['1084.0'], 'user_lock_for_resources': ['1084.0'], 'user_unlock_for_resources': ['1084.0'], 'user_completed': ['1092.0', '1092.0']}
# {'comp': ['7'], 'due': ['1105'], 'user_arrival': ['1085.0'], 'user_server_assigned': ['1085.0', '1088.7'], 'user_lock_for_resources': ['1085.0', '1088.7'], 'user_unlock_for_resources': ['1085.7', '1088.7'], 'user_rejected_not_enough_resources': ['1085.7'], 'user_completed': ['1095.7', '1095.7']}
# {'comp': ['9'], 'due': ['1105'], 'user_arrival': ['1086.0'], 'user_server_assigned': ['1086.0', '1089.9', '1091.8000000000002', '1094.7000000000003', '1097.6000000000004', '1101.5000000000005', '1104.4000000000005'], 'user_lock_for_resources': ['1086.0', '1089.9', '1091.8000000000002', '1094.7000000000003', '1097.6000000000004', '1101.5000000000005', '1104.4000000000005'], 'user_unlock_for_resources': ['1086.9', '1090.8000000000002', '1092.7000000000003', '1095.6000000000004', '1098.5000000000005', '1102.4000000000005', '1105.0'], 'user_rejected_not_enough_resources': ['1086.9', '1090.8000000000002', '1092.7000000000003', '1095.6000000000004', '1098.5000000000005', '1102.4000000000005'], 'user_rejected_not_enough_time': ['1105.0'], 'user_expired': ['1105.0']}
# {'comp': ['1'], 'due': ['1097'], 'user_arrival': ['1086.0'], 'user_server_assigned': ['1086.0'], 'user_lock_for_resources': ['1086.0'], 'user_unlock_for_resources': ['1086.0'], 'user_completed': ['1087.0', '1087.0']}
# {'comp': ['2'], 'due': ['1102'], 'user_arrival': ['1087.0'], 'user_server_assigned': ['1087.0'], 'user_lock_for_resources': ['1087.0'], 'user_unlock_for_resources': ['1087.0'], 'user_completed': ['1089.0', '1089.0']}
# {'comp': ['1'], 'due': ['1097'], 'user_arrival': ['1087.0'], 'user_rejected_all_servers_out': ['1087.0', '1088.0', '1091.0', '1093.0', '1096.0', '1098.0'], 'user_expired': ['1098.0']}
# {'comp': ['1'], 'due': ['1104'], 'user_arrival': ['1087.0'], 'user_server_assigned': ['1087.0'], 'user_lock_for_resources': ['1087.0'], 'user_unlock_for_resources': ['1087.0'], 'user_completed': ['1088.0', '1088.0']}
# {'comp': ['4'], 'due': ['1101'], 'user_arrival': ['1088.0'], 'user_server_assigned': ['1088.0'], 'user_lock_for_resources': ['1088.0'], 'user_unlock_for_resources': ['1088.0'], 'user_completed': ['1092.0', '1092.0']}
# {'comp': ['8'], 'due': ['1106'], 'user_arrival': ['1089.0'], 'user_server_assigned': ['1089.0'], 'user_lock_for_resources': ['1089.0'], 'user_unlock_for_resources': ['1089.0'], 'user_completed': ['1097.0', '1097.0']}
# {'comp': ['8'], 'due': ['1103'], 'user_arrival': ['1089.0'], 'user_server_assigned': ['1089.0'], 'user_lock_for_resources': ['1089.0'], 'user_unlock_for_resources': ['1089.0'], 'user_completed': ['1097.0', '1097.0']}
# {'comp': ['7'], 'due': ['1108'], 'user_arrival': ['1089.0'], 'user_server_assigned': ['1089.0', '1091.7', '1095.4', '1098.1000000000001', '1099.8000000000002', '1103.5000000000002', '1107.2000000000003', '1110.9000000000003'], 'user_lock_for_resources': ['1089.0', '1091.7', '1095.4', '1098.1000000000001', '1099.8000000000002', '1103.5000000000002', '1107.2000000000003', '1110.9000000000003'], 'user_unlock_for_resources': ['1089.7', '1092.4', '1096.1000000000001', '1098.8000000000002', '1100.5000000000002', '1104.2000000000003', '1107.9000000000003', '1110.9000000000003'], 'user_rejected_not_enough_resources': ['1089.7', '1092.4', '1096.1000000000001', '1098.8000000000002', '1100.5000000000002', '1104.2000000000003', '1107.9000000000003'], 'user_rejected_not_enough_time': ['1110.9000000000003'], 'user_expired': ['1110.9000000000003']}
# {'comp': ['8'], 'due': ['1099'], 'user_arrival': ['1089.0'], 'user_server_assigned': ['1089.0', '1091.8', '1095.6', '1099.3999999999999'], 'user_lock_for_resources': ['1089.0', '1091.8', '1095.6', '1099.3999999999999'], 'user_unlock_for_resources': ['1089.8', '1092.6', '1096.3999999999999', '1099.3999999999999'], 'user_rejected_not_enough_resources': ['1089.8', '1092.6', '1096.3999999999999'], 'user_rejected_not_enough_time': ['1099.3999999999999'], 'user_expired': ['1099.3999999999999']}
# {'comp': ['7'], 'due': ['1100'], 'user_arrival': ['1090.0'], 'user_server_assigned': ['1090.0', '1091.7', '1093.4', '1097.1000000000001', '1100.8000000000002'], 'user_lock_for_resources': ['1090.0', '1091.7', '1093.4', '1097.1000000000001', '1100.8000000000002'], 'user_unlock_for_resources': ['1090.7', '1092.4', '1094.1000000000001', '1097.8000000000002', '1100.8000000000002'], 'user_rejected_not_enough_resources': ['1090.7', '1092.4', '1094.1000000000001', '1097.8000000000002'], 'user_rejected_not_enough_time': ['1100.8000000000002'], 'user_expired': ['1100.8000000000002']}
# {'comp': ['2'], 'due': ['1108'], 'user_arrival': ['1091.0'], 'user_server_assigned': ['1091.0'], 'user_lock_for_resources': ['1091.0'], 'user_unlock_for_resources': ['1091.0'], 'user_completed': ['1093.0', '1093.0']}
# {'comp': ['6'], 'due': ['1102'], 'user_arrival': ['1091.0'], 'user_server_assigned': ['1091.0', '1093.6', '1097.1999999999998', '1098.7999999999997', '1100.3999999999996', '1103.9999999999995'], 'user_lock_for_resources': ['1091.0', '1093.6', '1097.1999999999998', '1098.7999999999997', '1100.3999999999996', '1103.9999999999995'], 'user_unlock_for_resources': ['1091.6', '1094.1999999999998', '1097.7999999999997', '1099.3999999999996', '1100.9999999999995', '1103.9999999999995'], 'user_rejected_not_enough_resources': ['1091.6', '1094.1999999999998', '1097.7999999999997', '1099.3999999999996', '1100.9999999999995'], 'user_rejected_not_enough_time': ['1103.9999999999995'], 'user_expired': ['1103.9999999999995']}
# {'comp': ['6'], 'due': ['1107'], 'user_arrival': ['1092.0'], 'user_server_assigned': ['1092.0', '1093.6', '1096.1999999999998', '1097.7999999999997', '1100.3999999999996', '1102.9999999999995', '1105.5999999999995', '1109.1999999999994'], 'user_lock_for_resources': ['1092.0', '1093.6', '1096.1999999999998', '1097.7999999999997', '1100.3999999999996', '1102.9999999999995', '1105.5999999999995', '1109.1999999999994'], 'user_unlock_for_resources': ['1092.6', '1094.1999999999998', '1096.7999999999997', '1098.3999999999996', '1100.9999999999995', '1103.5999999999995', '1106.1999999999994', '1109.1999999999994'], 'user_rejected_not_enough_resources': ['1092.6', '1094.1999999999998', '1096.7999999999997', '1098.3999999999996', '1100.9999999999995', '1103.5999999999995', '1106.1999999999994'], 'user_rejected_not_enough_time': ['1109.1999999999994'], 'user_expired': ['1109.1999999999994']}
# {'comp': ['4'], 'due': ['1108'], 'user_arrival': ['1092.0'], 'user_server_assigned': ['1092.0', '1093.4'], 'user_lock_for_resources': ['1092.0', '1093.4'], 'user_unlock_for_resources': ['1092.4', '1093.4'], 'user_rejected_not_enough_resources': ['1092.4'], 'user_completed': ['1097.4', '1097.4']}
# {'comp': ['1'], 'due': ['1104'], 'user_arrival': ['1092.0'], 'user_server_assigned': ['1092.0', '1094.1', '1095.1999999999998'], 'user_lock_for_resources': ['1092.0', '1094.1', '1095.1999999999998'], 'user_unlock_for_resources': ['1092.1', '1094.1999999999998', '1095.1999999999998'], 'user_rejected_not_enough_resources': ['1092.1', '1094.1999999999998'], 'user_completed': ['1096.1999999999998', '1096.1999999999998']}
# {'comp': ['6'], 'due': ['1111'], 'user_arrival': ['1092.0'], 'user_server_assigned': ['1092.0'], 'user_lock_for_resources': ['1092.0'], 'user_unlock_for_resources': ['1092.0'], 'user_completed': ['1098.0', '1098.0']}
# {'comp': ['6'], 'due': ['1112'], 'user_arrival': ['1093.0'], 'user_rejected_all_servers_out': ['1093.0', '1096.0', '1097.0', '1100.0', '1103.0', '1105.0', '1108.0', '1110.0', '1112.0'], 'user_expired': ['1112.0']}
# {'comp': ['8'], 'due': ['1113'], 'user_arrival': ['1095.0'], 'user_server_assigned': ['1095.0'], 'user_lock_for_resources': ['1095.0'], 'user_unlock_for_resources': ['1095.0'], 'user_completed': ['1103.0', '1103.0']}
# {'comp': ['1'], 'due': ['1114'], 'user_arrival': ['1095.0'], 'user_server_assigned': ['1095.0', '1096.1', '1098.1999999999998'], 'user_lock_for_resources': ['1095.0', '1096.1', '1098.1999999999998'], 'user_unlock_for_resources': ['1095.1', '1096.1999999999998', '1098.1999999999998'], 'user_rejected_not_enough_resources': ['1095.1', '1096.1999999999998'], 'user_completed': ['1099.1999999999998', '1099.1999999999998']}
# {'comp': ['4'], 'due': ['1111'], 'user_arrival': ['1096.0'], 'user_server_assigned': ['1096.0', '1099.4', '1102.8000000000002', '1106.2000000000003', '1107.6000000000004', '1109.0000000000005', '1111.4000000000005'], 'user_lock_for_resources': ['1096.0', '1099.4', '1102.8000000000002', '1106.2000000000003', '1107.6000000000004', '1109.0000000000005', '1111.4000000000005'], 'user_unlock_for_resources': ['1096.4', '1099.8000000000002', '1103.2000000000003', '1106.6000000000004', '1108.0000000000005', '1109.4000000000005', '1111.4000000000005'], 'user_rejected_not_enough_resources': ['1096.4', '1099.8000000000002', '1103.2000000000003', '1106.6000000000004', '1108.0000000000005', '1109.4000000000005'], 'user_rejected_not_enough_time': ['1111.4000000000005'], 'user_expired': ['1111.4000000000005']}
# {'comp': ['4'], 'due': ['1109'], 'user_arrival': ['1097.0'], 'user_server_assigned': ['1097.0'], 'user_lock_for_resources': ['1097.0'], 'user_unlock_for_resources': ['1097.0'], 'user_completed': ['1101.0', '1101.0']}
# {'comp': ['4'], 'due': ['1113'], 'user_arrival': ['1098.0'], 'user_server_assigned': ['1098.0'], 'user_lock_for_resources': ['1098.0'], 'user_unlock_for_resources': ['1098.0'], 'user_completed': ['1102.0', '1102.0']}
# {'comp': ['2'], 'due': ['1115'], 'user_arrival': ['1098.0'], 'user_server_assigned': ['1098.0', '1100.2', '1101.4', '1103.6000000000001', '1104.8000000000002', '1107.0000000000002', '1108.2000000000003', '1111.4000000000003', '1114.6000000000004', '1116.8000000000004'], 'user_lock_for_resources': ['1098.0', '1100.2', '1101.4', '1103.6000000000001', '1104.8000000000002', '1107.0000000000002', '1108.2000000000003', '1111.4000000000003', '1114.6000000000004', '1116.8000000000004'], 'user_unlock_for_resources': ['1098.2', '1100.4', '1101.6000000000001', '1103.8000000000002', '1105.0000000000002', '1107.2000000000003', '1108.4000000000003', '1111.6000000000004', '1114.8000000000004', '1116.8000000000004'], 'user_rejected_not_enough_resources': ['1098.2', '1100.4', '1101.6000000000001', '1103.8000000000002', '1105.0000000000002', '1107.2000000000003', '1108.4000000000003', '1111.6000000000004', '1114.8000000000004'], 'user_rejected_not_enough_time': ['1116.8000000000004'], 'user_expired': ['1116.8000000000004']}
# {'comp': ['10'], 'due': ['1116'], 'user_arrival': ['1099.0'], 'user_server_assigned': ['1099.0'], 'user_lock_for_resources': ['1099.0'], 'user_unlock_for_resources': ['1099.0'], 'user_completed': ['1109.0', '1109.0']}
# {'comp': ['4'], 'due': ['1117'], 'user_arrival': ['1099.0'], 'user_server_assigned': ['1099.0'], 'user_lock_for_resources': ['1099.0'], 'user_unlock_for_resources': ['1099.0'], 'user_completed': ['1103.0', '1103.0']}
# {'comp': ['9'], 'due': ['1112'], 'user_arrival': ['1099.0'], 'user_rejected_all_servers_out': ['1099.0', '1102.0', '1105.0', '1108.0', '1109.0', '1111.0', '1112.0'], 'user_expired': ['1112.0']}
# {'comp': ['3'], 'due': ['1118'], 'user_arrival': ['1099.0'], 'user_server_assigned': ['1099.0', '1100.3', '1101.6', '1102.8999999999999', '1106.1999999999998', '1107.4999999999998', '1109.7999999999997', '1111.0999999999997', '1113.3999999999996', '1115.6999999999996', '1118.9999999999995'], 'user_lock_for_resources': ['1099.0', '1100.3', '1101.6', '1102.8999999999999', '1106.1999999999998', '1107.4999999999998', '1109.7999999999997', '1111.0999999999997', '1113.3999999999996', '1115.6999999999996', '1118.9999999999995'], 'user_unlock_for_resources': ['1099.3', '1100.6', '1101.8999999999999', '1103.1999999999998', '1106.4999999999998', '1107.7999999999997', '1110.0999999999997', '1111.3999999999996', '1113.6999999999996', '1115.9999999999995', '1118.9999999999995'], 'user_rejected_not_enough_resources': ['1099.3', '1100.6', '1101.8999999999999', '1103.1999999999998', '1106.4999999999998', '1107.7999999999997', '1110.0999999999997', '1111.3999999999996', '1113.6999999999996', '1115.9999999999995'], 'user_rejected_not_enough_time': ['1118.9999999999995'], 'user_expired': ['1118.9999999999995']}
# {'comp': ['8'], 'due': ['1122'], 'user_arrival': ['1102.0'], 'user_server_assigned': ['1102.0'], 'user_lock_for_resources': ['1102.0'], 'user_unlock_for_resources': ['1102.0'], 'user_completed': ['1110.0', '1110.0']}
# {'comp': ['5'], 'due': ['1344'], 'user_arrival': ['1327.0'], 'user_rejected_all_servers_out': ['1327.0', '1330.0', '1332.0', '1333.0', '1336.0', '1337.0', '1340.0', '1341.0', '1344.0'], 'user_expired': ['1344.0']}
# {'comp': ['1'], 'due': ['1370'], 'user_arrival': ['1351.0'], 'user_rejected_all_servers_out': ['1351.0', '1354.0', '1357.0', '1360.0', '1362.0', '1363.0', '1365.0', '1367.0', '1368.0', '1371.0'], 'user_expired': ['1371.0']}
# {'comp': ['2'], 'due': ['1409'], 'user_arrival': ['1392.0'], 'user_rejected_all_servers_out': ['1392.0', '1395.0', '1397.0', '1398.0', '1400.0', '1403.0', '1404.0', '1407.0', '1410.0'], 'user_expired': ['1410.0']}

# %%
print(df.columns)
# Out:
# Index(['comp', 'due', 'user_completed', 'user_arrival', 'user_expired',
#        'user_server_assigned', 'user_lock_for_resources',
#        'user_unlock_for_resources', 'user_rejected_not_enough_resources',
#        'user_rejected_not_enough_time', 'user_rejected_all_servers_out',
#        'user_interrupted'],
#       dtype='object')
